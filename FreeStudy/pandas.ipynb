# %%
import pandas

# %%
pandas.Series([25,30,22,28,35])
# Out:
# 0    25
# 1    30
# 2    22
# 3    28
# 4    35
# dtype: int64

# %%
import pandas as pd

# %%
ages = pd.Series([25,30,22,28,35])
ages
# Out:
# 0    25
# 1    30
# 2    22
# 3    28
# 4    35
# dtype: int64

# %%
data = [
    ["김철수",25,175],
    ["이영희",30,162],
    ["박지민",22,168]
]

data
# Out:
# [['김철수', 25, 175], ['이영희', 30, 162], ['박지민', 22, 168]]

# %%
df = pd.DataFrame(data, columns=["이름","나이","키"])
df
# Out:
#     이름  나이    키
# 0  김철수  25  175
# 1  이영희  30  162
# 2  박지민  22  168

# %%
data2 = {
    "이름": ["김철수", "이영희", "박지민"],
    "나이": [25,30,22],
    "키": [175,162,168]
}
df2 = pd.DataFrame(data2)
df2
# Out:
#     이름  나이    키
# 0  김철수  25  175
# 1  이영희  30  162
# 2  박지민  22  168

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            60 non-null     object
#  1   day_of_week     60 non-null     object
#  2   americano       58 non-null     float64
#  3   cafe_latte      59 non-null     float64
#  4   cappuccino      60 non-null     int64
#  5   lemon_ade       59 non-null     float64
#  6   grapefruit_ade  60 non-null     int64
#  7   herbal_tea      60 non-null     int64
#  8   chocolate_cake  60 non-null     int64
#  9   ny_cheese_cake  60 non-null     int64
#  10  carrot_cake     60 non-null     int64
#  11  tiramisu        60 non-null     int64
# dtypes: float64(3), int64(7), object(2)
# memory usage: 5.8+ KB

# %%
df = pd.read_csv("cafe_1.csv")
df.head()
# Out:
#          date day_of_week  americano  cafe_latte  cappuccino  lemon_ade  \
# 0  2025-01-01           수      218.0        68.0          78       62.0
# 1  2025-01-02           목      222.0        79.0         105       52.0
# 2  2025-01-03           금      215.0        30.0          94       45.0
# 3  2025-01-04           토      313.0       100.0         106       86.0
# 4  2025-01-05           일      311.0        82.0         137      101.0
#
#    grapefruit_ade  herbal_tea  chocolate_cake  ny_cheese_cake  carrot_cake  \
# 0              82          67               0               8            7
# 1              44          54              23              31            0
# 2             103          62              25               0            8
# 3             106          94              22              66           78
# 4              89          70              36              35           40
#
#    tiramisu
# 0         9
# 1         6
# 2        12
# 3        47
# 4        17

# %%
df.describe()
# Out:
#         americano  cafe_latte  cappuccino   lemon_ade  grapefruit_ade  \
# count   58.000000   59.000000   60.000000   59.000000       60.000000
# mean   250.620690   80.084746   99.583333   60.406780       79.033333
# std     66.880052   22.978467   18.723041   21.094303       25.909207
# min     20.000000   30.000000   56.000000   18.000000       25.000000
# 25%    218.000000   66.500000   86.500000   46.500000       62.500000
# 50%    222.500000   77.000000  100.500000   57.000000       80.500000
# 75%    309.000000   91.000000  109.250000   74.000000       96.000000
# max    500.000000  144.000000  148.000000  106.000000      145.000000
#
#        herbal_tea  chocolate_cake  ny_cheese_cake  carrot_cake    tiramisu
# count   60.000000       60.000000       60.000000    60.000000   60.000000
# mean    68.116667       31.183333       24.116667    24.516667   24.850000
# std     16.854403       21.496938       22.222367    18.587851   20.988152
# ...

# %%
df.describe().loc[['std', 'mean'],:]
# Out:
#        americano  cafe_latte  cappuccino  lemon_ade  grapefruit_ade  \
# std    66.880052   22.978467   18.723041  21.094303       25.909207
# mean  250.620690   80.084746   99.583333  60.406780       79.033333
#
#       herbal_tea  chocolate_cake  ny_cheese_cake  carrot_cake   tiramisu
# std    16.854403       21.496938       22.222367    18.587851  20.988152
# mean   68.116667       31.183333       24.116667    24.516667  24.850000

# %%
df[df['americano']>222]
# Out:
#           date day_of_week  americano  cafe_latte  cappuccino  lemon_ade  \
# 3   2025-01-04           토      313.0       100.0         106       86.0
# 4   2025-01-05           일      311.0        82.0         137      101.0
# 10  2025-01-11           토      325.0         NaN          97       80.0
# 11  2025-01-12           일      309.0       107.0         130      106.0
# 12  2025-01-13           월      224.0        44.0         105       52.0
# 14  2025-01-15           수      450.0        58.0          82       51.0
# 17  2025-01-18           토      317.0       118.0          97       91.0
# 18  2025-01-19           일      304.0       120.0         126      102.0
# 21  2025-01-22           수      226.0        58.0         104       25.0
# 23  2025-01-24           금      232.0        82.0         110       72.0
# 24  2025-01-25           토      308.0       144.0         148       90.0
# 25  2025-01-26           일      309.0        93.0         114       73.0
# ...

# %%
pivot_cafe = df.pivot_table(
    index='day_of_week',
    values=['americano','cafe_latte','ny_cheese_cake','chocolate_cake','carrot_cake','tiramisu'],
    aggfunc='mean'
)

pivot_cafe
# Out:
#               americano  cafe_latte  carrot_cake  chocolate_cake  \
# day_of_week
# 금            222.500000   75.444444    24.444444       30.222222
# 목            217.777778   79.000000    27.777778       33.888889
# 수            277.666667   62.333333    15.444444       26.222222
# 월            222.142857   66.375000    15.875000       35.875000
# 일            273.250000  100.250000    28.625000       34.000000
# 토            314.555556  109.250000    36.222222       40.777778
# 화            215.625000   70.875000    22.500000       16.500000
#
#              ny_cheese_cake   tiramisu
# day_of_week
# 금                 11.666667  22.111111
# 목                 18.666667  30.555556
# 수                 15.666667  10.777778
# 월                 17.500000  16.500000
# 일                 47.875000  32.375000
# 토                 43.666667  37.222222
# 화                 14.625000  24.250000

# %%
# prompt: 내 입력을 그대로 출력해주는 코드를 만들어줘 몇 줄의 문자열이 들어갈지는 랜덤인데 입력이 끝나면 알아서 반복을 종료해줘

while True:
    try:
        line = input()
        print(line)
    except EOFError:
        break

# %%
pd.DataFrame(data, index=['a','v','c'])
# Out:
#      0   1    2
# a  김철수  25  175
# v  이영희  30  162
# c  박지민  22  168

# %%
datap = {
    '손님' : ['철수','영희','민수','철수','영희','민수'],
    '메뉴' : ['짜장면','짬뽕','탕수육','짜장면','짬뽕','탕수육'],
    '개수' : [2,4,1,3,1,2]
}
dfp = pd.DataFrame(datap)
dfp
# Out:
#    손님   메뉴  개수
# 0  철수  짜장면   2
# 1  영희   짬뽕   4
# 2  민수  탕수육   1
# 3  철수  짜장면   3
# 4  영희   짬뽕   1
# 5  민수  탕수육   2

# %%
pc = dfp.pivot_table(
    index='손님',
    values='개수',
    aggfunc='sum'
)
pc
# Out:
#     개수
# 손님
# 민수   3
# 영희   5
# 철수   5

# %%
pd.crosstab(dfp['손님'],dfp['메뉴'], margins=True)
# Out:
# 메뉴   짜장면  짬뽕  탕수육  All
# 손님
# 민수     0   0    2    2
# 영희     0   2    0    2
# 철수     2   0    0    2
# All    2   2    2    6

# %%
df['month'] = df['date'].str[5:7]
dfpi = df.pivot_table(
    index='month',
    values=['americano','cafe_latte','ny_cheese_cake','chocolate_cake','carrot_cake','tiramisu'],
    aggfunc='sum'
)
dfpi.loc['sum'] = dfpi.sum(axis=0)
dfpi
# Out:
#        americano  cafe_latte  carrot_cake  chocolate_cake  ny_cheese_cake  \
# month
# 01        7538.0      2320.0        699.0           883.0           811.0
# 02        6683.0      2331.0        723.0           983.0           619.0
# 03         315.0        74.0         49.0             5.0            17.0
# sum      14536.0      4725.0       1471.0          1871.0          1447.0
#
#        tiramisu
# month
# 01        687.0
# 02        767.0
# 03         37.0
# sum      1491.0

# %%
df.groupby(['month', 'day_of_week']).sum()
# Out:
#                                                                 date  \
# month day_of_week
# 01    금            2025-01-032025-01-102025-01-172025-01-242025-0...
#       목            2025-01-022025-01-092025-01-162025-01-232025-0...
#       수            2025-01-012025-01-082025-01-152025-01-222025-0...
#       월                     2025-01-062025-01-132025-01-202025-01-27
#       일                     2025-01-052025-01-122025-01-192025-01-26
#       토                     2025-01-042025-01-112025-01-182025-01-25
#       화                     2025-01-072025-01-142025-01-212025-01-28
# 02    금                     2025-02-072025-02-142025-02-212025-02-28
#       목                     2025-02-062025-02-132025-02-202025-02-27
#       수                     2025-02-052025-02-122025-02-192025-02-26
#       월                     2025-02-032025-02-102025-02-172025-02-24
#       일                     2025-02-022025-02-092025-02-162025-02-23
# ...
